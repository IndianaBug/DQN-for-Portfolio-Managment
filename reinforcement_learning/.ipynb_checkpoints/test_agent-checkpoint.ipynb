# %%
from agent_DQN import DQN_agent
from utilis import plot_loss_portfolio

# %%
agent = DQN_agent(episodes = 100, T = 16)

for episode in range(1, agent.episodes + 1):

    agent.gather_samples()
    total_reward = agent.optimize(episode)

    if episode % 10 == 0:
        print(f"Episode: {episode}, Training_loss: {agent.training_losses[-1]}, Validation_loss: {agent.validation_losses[-1]}")

    patience_counter = 0
    # Early stoppping
    if agent.last_validation_loss < agent.best_val_loss:
        agent.best_val_loss = agent.last_validation_loss
        patience_counter = 0
    else:
        patience_counter += 1
    if patience_counter >= agent.patience:
        print(f'Early stopping at epoch {episode + 1}')
        break
# Out:
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\RL\agent_DQN.py:132: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:264.)
#   next_state = torch.FloatTensor(batch.next_state).to(device)
# Episode: 10, Training_loss: 9.092575073242188, Validation_loss: 8.395254135131836
# Episode: 20, Training_loss: 6.310103893280029, Validation_loss: 6.686923027038574
# Episode: 30, Training_loss: 6.470123767852783, Validation_loss: 6.466978073120117
# Episode: 40, Training_loss: 4.998012542724609, Validation_loss: 5.585906982421875
# Episode: 50, Training_loss: 5.3050713539123535, Validation_loss: 6.0652689933776855
# Episode: 60, Training_loss: 4.756812572479248, Validation_loss: 5.049352645874023
# Episode: 70, Training_loss: 4.027493000030518, Validation_loss: 4.474992752075195
# Episode: 80, Training_loss: 4.988778114318848, Validation_loss: 3.9089818000793457
# Episode: 90, Training_loss: 4.874048233032227, Validation_loss: 3.5332720279693604
# Episode: 100, Training_loss: 3.2053239345550537, Validation_loss: 3.3717103004455566

# %%
plot_loss_portfolio(agent.training_losses, agent.validation_losses, agent.train_env.portfolio)
