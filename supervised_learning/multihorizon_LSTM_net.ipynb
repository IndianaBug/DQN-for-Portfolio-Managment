# %%
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import get_scorer
from numpy.random import seed
from pylab import rcParams
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Reshape
from keras.utils import plot_model
# from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras.optimizers import Adam, RMSprop
import math
from pandas import DataFrame
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import DateOffset
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
import math
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utilis import get_dataset, mean_absolute_percentage_error, plot_train_history

days_ahead = 5
# Out:
# WARNING:tensorflow:From C:\coding\OOED\ooed\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def run_nets(horizon, number_lags):

    read_df = get_dataset(mode='eval', horizon=horizon, number_lags=number_lags)


    # Split data into train test validation
    TRAIN_SPLIT = math.ceil(len(read_df)*0.9*0.9)
    y_train = np.stack(read_df.iloc[:TRAIN_SPLIT, 0].values)
    x_train = np.expand_dims(read_df.iloc[:TRAIN_SPLIT, 1:].values, axis=2)
    y_val = np.stack(read_df.iloc[TRAIN_SPLIT:math.ceil(TRAIN_SPLIT/0.9), 0].values)
    x_val= np.expand_dims(read_df.iloc[TRAIN_SPLIT:math.ceil(TRAIN_SPLIT/0.9), 1:].values, axis=2)
    y_test = np.stack(read_df.iloc[math.ceil(TRAIN_SPLIT/0.9):, 0].values)
    x_test = np.expand_dims(read_df.iloc[math.ceil(TRAIN_SPLIT/0.9):, 1:].values, axis=2)

    # LSTM Architecture
    BATCH_SIZE = 32 # bacth size in batch-SGD/variants
    BUFFER_SIZE = 10000 # for shuffling the dataset
    train_univariate = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()# defaule is repeated till number of time batch run
    #https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat
    val_univariate = tf.data.Dataset.from_tensor_slices((x_val, y_val))
    val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.LSTM(128,
                                  return_sequences=True,
                                  input_shape=x_train.shape[-2:],
                                  activation='relu'
                                  ))
    model.add(tf.keras.layers.LSTM(64, activation='relu', return_sequences=True))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(tf.keras.layers.LSTM(32, activation='relu', return_sequences=False))
    model.add(Dense(32))
    model.add(Dropout(0.2))
    model.add(tf.keras.layers.Dense(horizon, activation='relu'))
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='mae')
    # Train and evaluate
    STEPS_PER_EPOCH = 10
    EPOCHS = 100
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)
    model.summary()
    multy_step_history = model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=STEPS_PER_EPOCH,
                      validation_data=val_univariate, validation_steps=10, callbacks=[callback])
    # Plot validation loss
    plot_train_history(multy_step_history, 'validation loss')
    # Calculate MAPE
    print("Evaluate model on test data")
    yhat = model.predict(x_test)
    predicted = yhat[:,-1]
    print("--------------------------------------------------------")
    print("test MAPE:", mean_absolute_percentage_error(y_test[:,-1], predicted), '%')
    print("-------------------------------------------------------")
    plt.plot(range(len(predicted)), predicted)
    plt.plot(range(len(y_test[:,-1])), y_test[:,-1])
    # Plot Accuracy
    true_trend_1 = y_test[:horizon,-1] - y_val[-horizon:,-1]
    true_trend_2 = y_test[horizon:len(y_test),-1] - y_test[:len(y_test)-horizon,-1]
    true_trend = [*true_trend_1, *true_trend_2]
    binary_true_trend = []
    for e in true_trend:
        if e > 0:
            binary_true_trend.append(1)
        else:
            binary_true_trend.append(0)


    predicted_trend_1 = yhat[:horizon,-1] - y_val[-horizon:,-1]
    predicted_trend_2= yhat[horizon:len(yhat),-1] - y_test[:len(y_test)-horizon,-1]
    predicted_trend = [*predicted_trend_1, *predicted_trend_2]

    binary_predicted_trend = []
    for e in predicted_trend:
        if e > 0:
            binary_predicted_trend.append(1)
        else:
            binary_predicted_trend.append(0)

    from sklearn.metrics import accuracy_score
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
    print("Trend Catch Accuracy:", accuracy_score(binary_true_trend, binary_predicted_trend) * 100,'%')
    cm = confusion_matrix(binary_true_trend, binary_predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return model

model_20 = run_nets(days_ahead, 20)
# Out:
# WARNING:tensorflow:From C:\coding\OOED\ooed\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 53, 128)           66560
#
#  lstm_1 (LSTM)               (None, 53, 64)            49408
#
#  dense (Dense)               (None, 53, 64)            4160
#
#  dropout (Dropout)           (None, 53, 64)            0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:From C:\coding\OOED\ooed\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 10/10 [==============================] - 4s 90ms/step - loss: 0.3808 - val_loss: 0.3652
# Epoch 2/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.2523 - val_loss: 0.4430
# Epoch 3/100
# 10/10 [==============================] - 0s 51ms/step - loss: 0.2305 - val_loss: 0.4122
# Epoch 4/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.1902 - val_loss: 0.2476
# Epoch 5/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.1612 - val_loss: 0.4486
# Epoch 6/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.2185 - val_loss: 0.2821
# Epoch 7/100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.1873 - val_loss: 0.3762
# Epoch 8/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.1881 - val_loss: 0.3104
# Epoch 9/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.1602 - val_loss: 0.2887
# Epoch 10/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.1259 - val_loss: 0.0604
# Epoch 11/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0963 - val_loss: 0.1312
# Epoch 12/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0894 - val_loss: 0.0491
# Epoch 13/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0959 - val_loss: 0.2240
# Epoch 14/100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0942 - val_loss: 0.1392
# Epoch 15/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0824 - val_loss: 0.0447
# Epoch 16/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0871 - val_loss: 0.1330
# Epoch 17/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0894 - val_loss: 0.0912
# Epoch 18/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0781 - val_loss: 0.0448
# Epoch 19/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0833 - val_loss: 0.0731
# Epoch 20/100
# 10/10 [==============================] - 0s 47ms/step - loss: 0.0763 - val_loss: 0.0301
# Epoch 21/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0734 - val_loss: 0.1710
# Epoch 22/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0826 - val_loss: 0.0540
# Epoch 23/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0817 - val_loss: 0.0310
# Epoch 24/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0723 - val_loss: 0.0390
# Epoch 25/100
# 10/10 [==============================] - 0s 51ms/step - loss: 0.0681 - val_loss: 0.0290
# Epoch 26/100
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0690 - val_loss: 0.0588
# Epoch 27/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0675 - val_loss: 0.0792
# Epoch 28/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0754 - val_loss: 0.0263
# Epoch 29/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0711 - val_loss: 0.0449
# Epoch 30/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0651 - val_loss: 0.0916
# Epoch 31/100
# 10/10 [==============================] - 0s 51ms/step - loss: 0.0663 - val_loss: 0.0276
# Epoch 32/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0686 - val_loss: 0.0381
# Epoch 33/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0617 - val_loss: 0.0348
# Epoch 34/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0602 - val_loss: 0.1157
# Epoch 35/100
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0639 - val_loss: 0.0325
# Epoch 36/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0606 - val_loss: 0.0425
# Epoch 37/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0658 - val_loss: 0.0313
# Epoch 38/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0734 - val_loss: 0.0795
# Epoch 39/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0660 - val_loss: 0.0564
# Epoch 40/100
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0543 - val_loss: 0.0357
# Epoch 41/100
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0582 - val_loss: 0.0276
# Epoch 42/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0658 - val_loss: 0.1165
# Epoch 43/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0642 - val_loss: 0.0367
# Epoch 44/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0601 - val_loss: 0.0229
# Epoch 45/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0649 - val_loss: 0.1211
# Epoch 46/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0616 - val_loss: 0.0422
# Epoch 47/100
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0623 - val_loss: 0.0231
# Epoch 48/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0610 - val_loss: 0.0382
# Epoch 49/100
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0543 - val_loss: 0.0862
# Epoch 50/100
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0596 - val_loss: 0.0466
# Evaluate model on test data
# 4/4 [==============================] - 0s 13ms/step
# --------------------------------------------------------
# test MAPE: 5.632215408197689 %
# -------------------------------------------------------
# Trend Catch Accuracy: 57.49999999999999 %

# %%
model_50 = run_nets(days_ahead, 50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 83, 128)           66560
#
#  lstm_4 (LSTM)               (None, 83, 64)            49408
#
#  dense_3 (Dense)             (None, 83, 64)            4160
#
#  dropout_2 (Dropout)         (None, 83, 64)            0
#
#  lstm_5 (LSTM)               (None, 32)                12416
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dropout_3 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 4s 117ms/step - loss: 0.4117 - val_loss: 0.4697
# Epoch 2/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.2623 - val_loss: 0.4761
# Epoch 3/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.2550 - val_loss: 0.2958
# Epoch 4/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.2240 - val_loss: 0.2877
# Epoch 5/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.2095 - val_loss: 0.3589
# Epoch 6/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1627 - val_loss: 0.2226
# Epoch 7/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.1243 - val_loss: 0.1005
# Epoch 8/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1166 - val_loss: 0.0755
# Epoch 9/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.1082 - val_loss: 0.0890
# Epoch 10/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0985 - val_loss: 0.0644
# Epoch 11/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0994 - val_loss: 0.0611
# Epoch 12/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0942 - val_loss: 0.0872
# Epoch 13/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0813 - val_loss: 0.0560
# Epoch 14/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0856 - val_loss: 0.1463
# Epoch 15/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0913 - val_loss: 0.1338
# Epoch 16/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0941 - val_loss: 0.0572
# Epoch 17/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0841 - val_loss: 0.1259
# Epoch 18/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0833 - val_loss: 0.0520
# Epoch 19/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0977 - val_loss: 0.1068
# Epoch 20/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0776 - val_loss: 0.0920
# Epoch 21/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0821 - val_loss: 0.0575
# Epoch 22/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0858 - val_loss: 0.1736
# Epoch 23/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0881 - val_loss: 0.0571
# Epoch 24/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0820 - val_loss: 0.1483
# Epoch 25/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0872 - val_loss: 0.0495
# Epoch 26/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0810 - val_loss: 0.0884
# Epoch 27/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0765 - val_loss: 0.0545
# Epoch 28/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0764 - val_loss: 0.0765
# Epoch 29/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0694 - val_loss: 0.0733
# Epoch 30/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0735 - val_loss: 0.0623
# Epoch 31/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.0708 - val_loss: 0.0688
# Epoch 32/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0644 - val_loss: 0.0672
# Epoch 33/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0719 - val_loss: 0.1124
# Epoch 34/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0757 - val_loss: 0.0553
# Epoch 35/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0831 - val_loss: 0.1144
# Epoch 36/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0763 - val_loss: 0.0867
# Epoch 37/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0792 - val_loss: 0.0528
# Epoch 38/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0665 - val_loss: 0.0497
# Epoch 39/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0679 - val_loss: 0.0868
# Epoch 40/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0632 - val_loss: 0.0584
# Epoch 41/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0647 - val_loss: 0.0482
# Epoch 42/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0710 - val_loss: 0.0843
# Epoch 43/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0673 - val_loss: 0.0935
# Epoch 44/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0634 - val_loss: 0.0452
# Epoch 45/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0653 - val_loss: 0.0861
# Epoch 46/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0624 - val_loss: 0.0435
# Epoch 47/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0627 - val_loss: 0.0445
# Epoch 48/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0629 - val_loss: 0.0690
# Epoch 49/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0595 - val_loss: 0.0353
# Epoch 50/100
# 10/10 [==============================] - 1s 85ms/step - loss: 0.0546 - val_loss: 0.0636
# Epoch 51/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0584 - val_loss: 0.0513
# Epoch 52/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0594 - val_loss: 0.0265
# Epoch 53/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0628 - val_loss: 0.0748
# Epoch 54/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0543 - val_loss: 0.0912
# Epoch 55/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0561 - val_loss: 0.0529
# Epoch 56/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0584 - val_loss: 0.1122
# Epoch 57/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0556 - val_loss: 0.0628
# Epoch 58/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0604 - val_loss: 0.0761
# Epoch 59/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0521 - val_loss: 0.0750
# Epoch 60/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0608 - val_loss: 0.1074
# Epoch 61/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0604 - val_loss: 0.0305
# Epoch 62/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0528 - val_loss: 0.0655
# Epoch 63/100
# 10/10 [==============================] - 1s 81ms/step - loss: 0.0515 - val_loss: 0.0885
# Epoch 64/100
# 10/10 [==============================] - 1s 88ms/step - loss: 0.0511 - val_loss: 0.0512
# Epoch 65/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0517 - val_loss: 0.0608
# Epoch 66/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0455 - val_loss: 0.0416
# Epoch 67/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0503 - val_loss: 0.0411
# Epoch 68/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0558 - val_loss: 0.0438
# Epoch 69/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0541 - val_loss: 0.0441
# Epoch 70/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0624 - val_loss: 0.0744
# Epoch 71/100
# 10/10 [==============================] - 1s 84ms/step - loss: 0.0672 - val_loss: 0.0289
# Epoch 72/100
# 10/10 [==============================] - 1s 77ms/step - loss: 0.0548 - val_loss: 0.0451
# Epoch 73/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0516 - val_loss: 0.0279
# Epoch 74/100
# 10/10 [==============================] - 1s 83ms/step - loss: 0.0516 - val_loss: 0.0706
# Epoch 75/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0499 - val_loss: 0.0325
# Epoch 76/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0477 - val_loss: 0.0457
# Evaluate model on test data
# 4/4 [==============================] - 1s 24ms/step
# --------------------------------------------------------
# test MAPE: 3.8835572515754215 %
# -------------------------------------------------------
# Trend Catch Accuracy: 60.83333333333333 %

# %%
model_100 = run_nets(days_ahead, 100)
plt.ylim(0, 1)  # Set y-axis limits
# Out:
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:218: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[f'lag_{period}'] = read_df['close'].shift(periods = period, axis = 0)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:228: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df['multy_close'] = multy_variate_Closing_Price
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df.insert(0, 'multy_close', column_to_move)
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 133, 128)          66560
#
#  lstm_10 (LSTM)              (None, 133, 64)           49408
#
#  dense_9 (Dense)             (None, 133, 64)           4160
#
#  dropout_6 (Dropout)         (None, 133, 64)           0
#
#  lstm_11 (LSTM)              (None, 32)                12416
#
#  dense_10 (Dense)            (None, 32)                1056
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 4s 166ms/step - loss: 0.3976 - val_loss: 1.4582
# Epoch 2/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.2114 - val_loss: 0.3256
# Epoch 3/100
# 10/10 [==============================] - 1s 116ms/step - loss: 0.1971 - val_loss: 0.3053
# Epoch 4/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1753 - val_loss: 0.2526
# Epoch 5/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1805 - val_loss: 0.5278
# Epoch 6/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.2026 - val_loss: 0.2330
# Epoch 7/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.1685 - val_loss: 0.3517
# Epoch 8/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1455 - val_loss: 0.1103
# Epoch 9/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.1282 - val_loss: 0.4716
# Epoch 10/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1323 - val_loss: 0.1243
# Epoch 11/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.1221 - val_loss: 0.0988
# Epoch 12/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.1091 - val_loss: 0.0894
# Epoch 13/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.1041 - val_loss: 0.1019
# Epoch 14/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1071 - val_loss: 0.0853
# Epoch 15/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.1046 - val_loss: 0.1729
# Epoch 16/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1108 - val_loss: 0.1200
# Epoch 17/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.1024 - val_loss: 0.1164
# Epoch 18/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0984 - val_loss: 0.1427
# Epoch 19/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.1023 - val_loss: 0.0742
# Epoch 20/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0936 - val_loss: 0.1228
# Epoch 21/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0895 - val_loss: 0.0725
# Epoch 22/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0899 - val_loss: 0.0561
# Epoch 23/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0856 - val_loss: 0.0715
# Epoch 24/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0777 - val_loss: 0.0598
# Epoch 25/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0802 - val_loss: 0.0494
# Epoch 26/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0703 - val_loss: 0.0377
# Epoch 27/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0737 - val_loss: 0.1138
# Epoch 28/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0847 - val_loss: 0.0519
# Epoch 29/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0760 - val_loss: 0.0971
# Epoch 30/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0705 - val_loss: 0.0315
# Epoch 31/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0708 - val_loss: 0.0464
# Epoch 32/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0727 - val_loss: 0.0717
# Epoch 33/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0799 - val_loss: 0.1329
# Epoch 34/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0737 - val_loss: 0.0307
# Epoch 35/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0725 - val_loss: 0.0592
# Epoch 36/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0700 - val_loss: 0.1193
# Epoch 37/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0671 - val_loss: 0.0558
# Epoch 38/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0661 - val_loss: 0.0625
# Epoch 39/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0686 - val_loss: 0.0267
# Epoch 40/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.0679 - val_loss: 0.0988
# Epoch 41/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0599 - val_loss: 0.0293
# Epoch 42/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0659 - val_loss: 0.1058
# Epoch 43/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0658 - val_loss: 0.0272
# Epoch 44/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.0644 - val_loss: 0.0479
# Epoch 45/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0624 - val_loss: 0.0487
# Epoch 46/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0614 - val_loss: 0.0353
# Epoch 47/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0632 - val_loss: 0.0719
# Epoch 48/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0593 - val_loss: 0.0530
# Epoch 49/100
# 10/10 [==============================] - 1s 119ms/step - loss: 0.0665 - val_loss: 0.1520
# Epoch 50/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0643 - val_loss: 0.0301
# Epoch 51/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0570 - val_loss: 0.0798
# Epoch 52/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0654 - val_loss: 0.0388
# Epoch 53/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0637 - val_loss: 0.0598
# Epoch 54/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0596 - val_loss: 0.0261
# Epoch 55/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0558 - val_loss: 0.0812
# Epoch 56/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0601 - val_loss: 0.0635
# Epoch 57/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0604 - val_loss: 0.0317
# Epoch 58/100
# 10/10 [==============================] - 1s 126ms/step - loss: 0.0585 - val_loss: 0.0612
# Epoch 59/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0547 - val_loss: 0.0244
# Epoch 60/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0611 - val_loss: 0.0981
# Epoch 61/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0600 - val_loss: 0.0290
# Epoch 62/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0583 - val_loss: 0.0776
# Epoch 63/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0547 - val_loss: 0.0235
# Epoch 64/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0527 - val_loss: 0.0826
# Epoch 65/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0604 - val_loss: 0.0334
# Epoch 66/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0506 - val_loss: 0.0238
# Epoch 67/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.0558 - val_loss: 0.0400
# Epoch 68/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0542 - val_loss: 0.0350
# Epoch 69/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0565 - val_loss: 0.0636
# Epoch 70/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0559 - val_loss: 0.0348
# Epoch 71/100
# 10/10 [==============================] - 1s 124ms/step - loss: 0.0547 - val_loss: 0.0254
# Epoch 72/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0533 - val_loss: 0.0357
# Epoch 73/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0586 - val_loss: 0.0608
# Epoch 74/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0510 - val_loss: 0.0233
# Epoch 75/100
# 10/10 [==============================] - 1s 121ms/step - loss: 0.0555 - val_loss: 0.0264
# Epoch 76/100
# 10/10 [==============================] - 1s 120ms/step - loss: 0.0586 - val_loss: 0.0920
# Evaluate model on test data
# 4/4 [==============================] - 0s 34ms/step
# --------------------------------------------------------
# test MAPE: 9.799940323027355 %
# -------------------------------------------------------
# Trend Catch Accuracy: 56.666666666666664 %
# (0.0, 1.0)

# %%
model_75 = run_nets(days_ahead, 75)
# Out:
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:249: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df[indicators.columns] = scaler_indicators.transform(indicators)
# C:\Users\Pasha\OneDrive\Desktop\OOED\OEOD-\SUP\utilis.py:253: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   read_df.insert(0, 'multy_close', column_to_move)
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 108, 128)          66560
#
#  lstm_13 (LSTM)              (None, 108, 64)           49408
#
#  dense_12 (Dense)            (None, 108, 64)           4160
#
#  dropout_8 (Dropout)         (None, 108, 64)           0
#
#  lstm_14 (LSTM)              (None, 32)                12416
#
#  dense_13 (Dense)            (None, 32)                1056
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 4s 137ms/step - loss: 0.3792 - val_loss: 0.2682
# Epoch 2/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.1996 - val_loss: 0.3403
# Epoch 3/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.1944 - val_loss: 0.3929
# Epoch 4/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1807 - val_loss: 0.2882
# Epoch 5/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.1613 - val_loss: 0.1069
# Epoch 6/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.1468 - val_loss: 0.1030
# Epoch 7/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1414 - val_loss: 0.1190
# Epoch 8/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.1345 - val_loss: 0.1074
# Epoch 9/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1141 - val_loss: 0.1076
# Epoch 10/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.1085 - val_loss: 0.0899
# Epoch 11/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.1097 - val_loss: 0.1089
# Epoch 12/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0989 - val_loss: 0.0816
# Epoch 13/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0913 - val_loss: 0.1078
# Epoch 14/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0936 - val_loss: 0.1394
# Epoch 15/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.1028 - val_loss: 0.0744
# Epoch 16/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0931 - val_loss: 0.1023
# Epoch 17/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0872 - val_loss: 0.1041
# Epoch 18/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.0900 - val_loss: 0.0720
# Epoch 19/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0910 - val_loss: 0.0948
# Epoch 20/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0888 - val_loss: 0.0761
# Epoch 21/100
# 10/10 [==============================] - 1s 95ms/step - loss: 0.0921 - val_loss: 0.0553
# Epoch 22/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0784 - val_loss: 0.1342
# Epoch 23/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0778 - val_loss: 0.0659
# Epoch 24/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0788 - val_loss: 0.0478
# Epoch 25/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0745 - val_loss: 0.1025
# Epoch 26/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0698 - val_loss: 0.0553
# Epoch 27/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.0741 - val_loss: 0.0528
# Epoch 28/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0712 - val_loss: 0.0828
# Epoch 29/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0642 - val_loss: 0.0424
# Epoch 30/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0631 - val_loss: 0.0618
# Epoch 31/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0714 - val_loss: 0.0823
# Epoch 32/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0719 - val_loss: 0.0343
# Epoch 33/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0674 - val_loss: 0.0906
# Epoch 34/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0696 - val_loss: 0.0645
# Epoch 35/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0697 - val_loss: 0.0303
# Epoch 36/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0657 - val_loss: 0.0696
# Epoch 37/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0655 - val_loss: 0.0271
# Epoch 38/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0635 - val_loss: 0.0909
# Epoch 39/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0611 - val_loss: 0.0578
# Epoch 40/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0584 - val_loss: 0.0274
# Epoch 41/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0621 - val_loss: 0.0721
# Epoch 42/100
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0670 - val_loss: 0.0815
# Epoch 43/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0660 - val_loss: 0.0710
# Epoch 44/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0529 - val_loss: 0.0274
# Epoch 45/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0592 - val_loss: 0.0516
# Epoch 46/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0554 - val_loss: 0.0245
# Epoch 47/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0545 - val_loss: 0.0403
# Epoch 48/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0566 - val_loss: 0.0834
# Epoch 49/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0573 - val_loss: 0.0379
# Epoch 50/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0582 - val_loss: 0.0241
# Epoch 51/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0578 - val_loss: 0.0741
# Epoch 52/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0513 - val_loss: 0.0224
# Epoch 53/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0531 - val_loss: 0.0584
# Epoch 54/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0587 - val_loss: 0.0440
# Epoch 55/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0533 - val_loss: 0.0310
# Epoch 56/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0540 - val_loss: 0.0266
# Epoch 57/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0624 - val_loss: 0.1397
# Epoch 58/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0581 - val_loss: 0.0261
# Epoch 59/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0558 - val_loss: 0.0361
# Epoch 60/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0532 - val_loss: 0.1081
# Epoch 61/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0581 - val_loss: 0.0282
# Epoch 62/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0547 - val_loss: 0.0235
# Evaluate model on test data
# 4/4 [==============================] - 0s 27ms/step
# --------------------------------------------------------
# test MAPE: 2.821522659702384 %
# -------------------------------------------------------
# Trend Catch Accuracy: 62.5 %

# %%
model_200

# %%
model_75.save('model_75.keras')
