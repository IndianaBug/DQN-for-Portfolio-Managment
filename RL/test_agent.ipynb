# %%
from agent_DQN import DQN_agent

# %%
from utilis import get_dataset

a = get_dataset()

a.columns
# Out:
# Index(['return', 'volume', 'ma_10', 'ema_10', 'ma_20', 'ema_20', 'ma_50',
#        'ema_50', 'ma_100', 'ema_100', 'rsi', 'upper_band', 'mid_band',
#        'lower_band', 'obv_diff_2', 'obv_diff_4', 'obv_diff_8', 'obv_diff_16',
#        'obv_diff_32', 'obv_diff_64', 'william', 'macd', 'signal', 'k_fast',
#        'd_fast', 'k_slow', 'd_slow', 'volatility', 'slope_2', 'slope_4',
#        'slope_6', 'slope_12', 'slope_24', 'slope_48', 'day_of_year_sin',
#        'day_of_week_sin', 'day_of_month_sin', 'week_of_year_sin', 'month_sin',
#        'quarter_sin'],
#       dtype='object')

# %%
agent = DQN_agent(episodes = 50)

for episode in range(1, agent.episodes + 1):
    
    reward = agent.optimize(episode)

    agent.train_env.print_stats(episode)
# Out:
# C:\coding\ooed_v2\OEOD-\RL\agent_DQN.py:134: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:264.)
#   next_state = torch.FloatTensor(batch.next_state).to(device)
# Early stopping at epoch 65
# Early stopping at epoch 74
# Early stopping at epoch 80
# Early stopping at epoch 46
# Early stopping at epoch 42
# Early stopping at epoch 73
# Early stopping at epoch 62
# Early stopping at epoch 131
# Early stopping at epoch 95
# Early stopping at epoch 34
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 agent = DQN_agent(episodes = 50)
#       3 for episode in range(1, agent.episodes + 1):
# ----> 5     done = agent.optimize(episode)
# ...
