# %%
from agent import Agent

# %%
agent = Agent()

for episode in range(1, agent.episodes + 1):
    
    done = agent.optimize(episode)

    if done:
        break
# Out:
# C:\coding\ooed_v2\rl\agent.py:125: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ..\torch\csrc\utils\tensor_new.cpp:264.)
#   next_state = torch.FloatTensor(batch.next_state).to(device)
# Early stopping at epoch 59
# dict_values([tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)])
# dict_values([tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)])
# dict_values([tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)])
# dict_values([tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.), tensor(0.)])
# ...

# %%
agent = Agent()

for i in [1, 2]:
    
    # Optimize
    agent.optimize(i)

    # Save portfolio values
    agent.train_env.print_stats(i)

    # Early stopping
# Out:
# Early stopping at epoch 154
# ...
