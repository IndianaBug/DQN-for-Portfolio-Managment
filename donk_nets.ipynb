# %%
# RoR = (Sale price - Purchase price) / Purchase price * 100

# Price

# %%
# Brute force backtester
# Machine Learning model
# Reinforcement Learnign algo 1
# Reinforcement learning algo 2
# Fine tune the best algorithm unless it is a brute force tester

# %%
# Calculate the returns, expected mean returns, and the risk.
# Define statistical trading strategy (at least one, maximum 2)
# Evaluate the efficacy of the trading strategy.
# Use at least one reinforcement learning algorithm for trading the assets (Q-learning, deep Q-learning)
# Evaluate the efficacy of the trading strategy.
# Fine-tune your algorithms.
# Compare and interpret the results.

# %%
 # (from 2019-01-01 to 2023-09-30)
 # Coca Cola company
 #

# %%
# import numpy as np
# import pandas as pd
# returns = data . pct_change ()
# ## ou
# returns =np . log ( data ) . diff () . dropna ()
# Cumulative rate of return
# Asset Expected Return = Sum ( Returns ) / Total Number Of Observations
# Market volatility
# Gain loss ration
# Sharpe ratio
# Compound annual growth rate


# Indicators to use
# Simple moving average strategy
# Exponentialy weighted moving average strategy
# RSI
# On balance volume
# MACD
# Williams R%  Strategy
# Stochastic Oscilator
# Bollinger Bands
# Pairs trading strtegy


# Simple moving average, 10, 20, 50, 100, 200
# RSI 14
# Bollinger Bands

# %%
# TPC do some exploratory analysis on why did we choose to work with 10, 20, 50, 100 ma. Make some plots of ma's to the price, explain that ma's often bounce from moving averages

# %%
# Predict the next 5, 10, 15 days rate of return
# By using 20, 30, 40 lags

# %%
def RSI(series, period):
    delta = series.diff().dropna()
    u = delta * 0
    d = u.copy()
    u[delta > 0] = delta[delta > 0]
    d[delta < 0] = -delta[delta < 0]
    u[u.index[period-1]] = np.mean( u[:period] ) #first value is sum of avg gains
    u = u.drop(u.index[:(period-1)])
    d[d.index[period-1]] = np.mean( d[:period] ) #first value is sum of avg losses
    d = d.drop(d.index[:(period-1)])
    rs = pd.DataFrame.ewm(u, com=period-1, adjust=False).mean() / \
         pd.DataFrame.ewm(d, com=period-1, adjust=False).mean()
    return 100 - 100 / (1 + rs)
def bollinger_bands(series: pd.Series, length: int = 20, *, num_stds: tuple[float, ...] = (2, 0, -2), prefix: str = '') -> pd.DataFrame:
    # Ref: https://stackoverflow.com/a/74283044/
    rolling = series.rolling(length)
    bband0 = rolling.mean()
    bband_std = rolling.std(ddof=0)
    return pd.DataFrame({f'{prefix}{num_std}': (bband0 + (bband_std * num_std)) for num_std in num_stds})
def get_wr(high, low, close, lookback):
    highh = high.rolling(lookback).max()
    lowl = low.rolling(lookback).min()
    wr = -100 * ((highh - close) / (highh - lowl))
    return wr
def MACD(
        cls,
        ohlc: DataFrame,
        period_fast: int = 12,
        period_slow: int = 26,
        signal: int = 9,
        column: str = "Close",
        adjust: bool = True,
    ) -> DataFrame:
    """
    MACD, MACD Signal and MACD difference.
    The MACD Line oscillates above and below the zero line, which is also known as the centerline.
    These crossovers signal that the 12-day EMA has crossed the 26-day EMA. The direction, of course, depends on the direction of the moving average cross.
    Positive MACD indicates that the 12-day EMA is above the 26-day EMA. Positive values increase as the shorter EMA diverges further from the longer EMA.
    This means upside momentum is increasing. Negative MACD values indicates that the 12-day EMA is below the 26-day EMA.
    Negative values increase as the shorter EMA diverges further below the longer EMA. This means downside momentum is increasing.
    Signal line crossovers are the most common MACD signals. The signal line is a 9-day EMA of the MACD Line.
    As a moving average of the indicator, it trails the MACD and makes it easier to spot MACD turns.
    A bullish crossover occurs when the MACD turns up and crosses above the signal line.
    A bearish crossover occurs when the MACD turns down and crosses below the signal line.
    """
    EMA_fast = pd.Series(
        ohlc[column].ewm(ignore_na=False, span=period_fast, adjust=adjust).mean(),
        name="EMA_fast",
    )
    EMA_slow = pd.Series(
        ohlc[column].ewm(ignore_na=False, span=period_slow, adjust=adjust).mean(),
        name="EMA_slow",
    )
    MACD = pd.Series(EMA_fast - EMA_slow, name="MACD")
    MACD_signal = pd.Series(
        MACD.ewm(ignore_na=False, span=signal, adjust=adjust).mean(), name="SIGNAL"
    )
    return pd.concat([MACD, MACD_signal], axis=1)

def stochastics(dataframe, low, high, close, k, d ):
    """
    Fast stochastic calculation
    # %K = (Current Close - Lowest Low)/
    (Highest High - Lowest Low) * 100
    # %D = 3-day SMA of %K

    Slow stochastic calculation
    # %K = %D of fast stochastic
    # %D = 3-day SMA of %K

    When %K crosses above %D, buy signal
    When the %K crosses below %D, sell signal
    """
    df = dataframe.copy()
    # Set minimum low and maximum high of the k stoch
    low_min  = df[low].rolling( window = k ).min()
    high_max = df[high].rolling( window = k ).max()
    # Fast Stochastic
    df['k_fast'] = 100 * (df[close] - low_min)/(high_max - low_min)
    df['k_fast'].ffill(inplace=True)
    df['d_fast'] = df['k_fast'].rolling(window = d).mean()
    # Slow Stochastic
    df['k_slow'] = df["d_fast"]
    df['d_slow'] = df['k_slow'].rolling(window = d).mean()
    return df
def plot_train_history(history, title):
  """
    Helper for neural nets
  """
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(len(loss))
  plt.figure()
  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()
  plt.grid()
  plt.show()
def mean_absolute_percentage_error(y_true, y_pred):
    """
      Error calculator
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218908 sha256=14c66c1bef392531c63e4da43175b9da4566cd38d885414c437aa2a9d51c5c06
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
import pandas_ta
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sys
import math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import get_scorer
from numpy.random import seed
from pylab import rcParams
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Reshape
from keras.utils import plot_model
# from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras.optimizers import Adam, RMSprop
import math
from pandas import DataFrame
from dateutil.relativedelta import relativedelta
from pandas.tseries.offsets import DateOffset
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import MinMaxScaler
import math
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load Coca's data
df = pd.DataFrame(yf.Ticker("KO").history(start='2019-01-01', end='2023-09-30', interval='1d'))
# Add 10, 20, 50, 100 moving averages, both simple and exponential
for length in [10, 20, 50, 100]:
    df[f'ma_{length}'] = df['Close'].rolling(length).mean()
    df[f'ema_{length}'] = df['Close'].ewm(span = length, adjust = False ).mean()
df['rsi'] = RSI(df["Close"], 14)
# Add bollinger bands
df['upper_band']= bollinger_bands(df["Close"])['2']
df['mid_band']= bollinger_bands(df["Close"])['0']
df['lower_band']= bollinger_bands(df["Close"])['-2']
# Add OBV
df['obv'] = (np.sign(df['Close'].diff()) * df['Volume']).fillna(0).cumsum()
# Add william r%
df['william'] = get_wr(df['High'], df['Low'], df['Close'], 14)
# Add MACD
df['macd'] = MACD(df, df)['MACD']
df['signal'] = MACD(df, df)['SIGNAL']
# Add stochastic
df = stochastics(df, 'Low', 'High', 'Close', 14, 3 )

# %%
# Predict the next 5, 10, 15 days rate of return
# By using 20, 30, 40 lags

# %%
def try_me_b(horizon, number_lags):
    # Length of the trainign dataset
    TRAIN_SPLIT = math.ceil(len(df.Close)*0.9*0.9)
    read_df = pd.DataFrame()
    read_df.index = pd.to_datetime(df.index)

    # Scale prices
    scaler = MinMaxScaler()
    scaler.fit(df['Close'].values[:TRAIN_SPLIT].reshape(-1, 1))
    read_df['Close'] = scaler.transform(df['Close'].values.reshape(-1, 1)).reshape(-1)

    # Add lags
    for period in range(horizon, number_lags+1):
      read_df[f'lag_{period}'] = read_df['Close'].shift(periods = period, axis = 0)

    # Add multy variate data
    multy_variate_Closing_Price = []
    for index in range(len(df)):
      if index > horizon-1:
        multy_variate_Closing_Price.append((read_df.Close.values[index-horizon:index]))

    # Add to dataframe
    read_df = read_df[horizon:]
    read_df['multy_close'] = multy_variate_Closing_Price
    read_df = read_df.drop(['Close'], axis=1)
    read_df = read_df.dropna()

    # Add indicators
    cols = ['ma_10', 'ema_10', 'ma_20', 'ema_20', 'ma_50', 'ema_50', 'ma_100',
          'ema_100', 'rsi', 'upper_band', 'mid_band', 'lower_band', 'obv',
          'william', 'macd', 'signal', 'k_fast', 'd_fast', 'k_slow', 'd_slow']
    indicators = df[cols]
    indicators = indicators.loc[indicators.index >= read_df.index[0]]
    scaler_indicators = MinMaxScaler()
    scaler_indicators.fit(indicators)
    read_df[indicators.columns] = scaler_indicators.transform(indicators)

    # Move target column to the beggining
    column_to_move = read_df.pop('multy_close')
    read_df.insert(0, 'multy_close', column_to_move)

    read_df = read_df.dropna()

    # Split data into train test validation
    TRAIN_SPLIT = math.ceil(len(read_df)*0.9*0.9)
    y_train = np.stack(read_df.iloc[:TRAIN_SPLIT, 0].values)
    x_train = np.expand_dims(read_df.iloc[:TRAIN_SPLIT, 1:].values, axis=2)
    y_val = np.stack(read_df.iloc[TRAIN_SPLIT:math.ceil(TRAIN_SPLIT/0.9), 0].values)
    x_val= np.expand_dims(read_df.iloc[TRAIN_SPLIT:math.ceil(TRAIN_SPLIT/0.9), 1:].values, axis=2)
    y_test = np.stack(read_df.iloc[math.ceil(TRAIN_SPLIT/0.9):, 0].values)
    x_test = np.expand_dims(read_df.iloc[math.ceil(TRAIN_SPLIT/0.9):, 1:].values, axis=2)

    # LSTM Architecture
    BATCH_SIZE = 32 # bacth size in batch-SGD/variants
    BUFFER_SIZE = 10000 # for shuffling the dataset
    train_univariate = tf.data.Dataset.from_tensor_slices((x_train, y_train))
    train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()# defaule is repeated till number of time batch run
    #https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat
    val_univariate = tf.data.Dataset.from_tensor_slices((x_val, y_val))
    val_univariate = val_univariate.batch(BATCH_SIZE).repeat()
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.LSTM(128,
                                  return_sequences=True,
                                  input_shape=x_train.shape[-2:],
                                  activation='relu'
                                  ))
    model.add(tf.keras.layers.LSTM(64, activation='relu', return_sequences=True))
    model.add(Dense(64))
    model.add(Dropout(0.3))
    model.add(tf.keras.layers.LSTM(32, activation='relu', return_sequences=False))
    model.add(Dense(32))
    model.add(Dropout(0.2))
    model.add(tf.keras.layers.Dense(horizon, activation='relu'))
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=opt, loss='mae')
    # Train and evaluate
    STEPS_PER_EPOCH = 10
    EPOCHS = 100
    callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=4)
    model.summary()
    multy_step_history = model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=STEPS_PER_EPOCH,
                      validation_data=val_univariate, validation_steps=10, callbacks=[callback])
    # Plot validation loss
    plot_train_history(multy_step_history, 'validation loss')
    # Calculate MAPE
    print("Evaluate model on test data")
    yhat = model.predict(x_test)
    predicted = yhat[:,-1]
    print("--------------------------------------------------------")
    print("test MAPE:", mean_absolute_percentage_error(y_test[:,-1], predicted), '%')
    print("-------------------------------------------------------")
    plt.plot(range(len(predicted)), predicted)
    plt.plot(range(len(y_test[:,-1])), y_test[:,-1])
    # Plot Accuracy
    true_trend_1 = y_test[:horizon,-1] - y_val[-horizon:,-1]
    true_trend_2 = y_test[horizon:len(y_test),-1] - y_test[:len(y_test)-horizon,-1]
    true_trend = [*true_trend_1, *true_trend_2]
    binary_true_trend = []
    for e in true_trend:
        if e > 0:
            binary_true_trend.append(1)
        else:
            binary_true_trend.append(0)


    predicted_trend_1 = yhat[:horizon,-1] - y_val[-horizon:,-1]
    predicted_trend_2= yhat[horizon:len(yhat),-1] - yhat[:len(yhat)-horizon,-1]
    predicted_trend = [*predicted_trend_1, *predicted_trend_2]

    binary_predicted_trend = []
    for e in predicted_trend:
        if e > 0:
            binary_predicted_trend.append(1)
        else:
            binary_predicted_trend.append(0)

    from sklearn.metrics import accuracy_score
    from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
    print("Trend Catch Accuracy:", accuracy_score(binary_true_trend, binary_predicted_trend) * 100,'%')
    cm = confusion_matrix(binary_true_trend, binary_predicted_trend)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.show()
    return "Try me again B"

try_me_b(5, 20)
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_84 (LSTM)              (None, 36, 128)           66560
#
#  lstm_85 (LSTM)              (None, 36, 64)            49408
#
#  dense_84 (Dense)            (None, 36, 64)            4160
#
#  dropout_56 (Dropout)        (None, 36, 64)            0
#
#  lstm_86 (LSTM)              (None, 32)                12416
#
#  dense_85 (Dense)            (None, 32)                1056
#
#  dropout_57 (Dropout)        (None, 32)                0
#
#  dense_86 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 6s 118ms/step - loss: 0.4533 - val_loss: 0.5024
# Epoch 2/100
# 10/10 [==============================] - 1s 74ms/step - loss: 0.2579 - val_loss: 0.2584
# Epoch 3/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.1542 - val_loss: 0.1538
# Epoch 4/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.1241 - val_loss: 0.0893
# Epoch 5/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.1086 - val_loss: 0.0483
# Epoch 6/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0967 - val_loss: 0.0937
# Epoch 7/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0931 - val_loss: 0.1129
# Epoch 8/100
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0900 - val_loss: 0.0364
# Epoch 9/100
# 10/10 [==============================] - 1s 73ms/step - loss: 0.0898 - val_loss: 0.0458
# Epoch 10/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0812 - val_loss: 0.0924
# Epoch 11/100
# 10/10 [==============================] - 1s 129ms/step - loss: 0.0896 - val_loss: 0.0273
# Epoch 12/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0794 - val_loss: 0.0770
# Epoch 13/100
# 10/10 [==============================] - 1s 82ms/step - loss: 0.0815 - val_loss: 0.0434
# Epoch 14/100
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0742 - val_loss: 0.0704
# Epoch 15/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0780 - val_loss: 0.0517
# Epoch 16/100
# 10/10 [==============================] - 1s 75ms/step - loss: 0.0746 - val_loss: 0.0302
# Epoch 17/100
# 10/10 [==============================] - 1s 78ms/step - loss: 0.0828 - val_loss: 0.0747
# Epoch 18/100
# 10/10 [==============================] - 1s 76ms/step - loss: 0.0765 - val_loss: 0.0643
# Evaluate model on test data
# 4/4 [==============================] - 1s 16ms/step
# --------------------------------------------------------
# test MAPE: 9.313566826123559 %
# -------------------------------------------------------
# Trend Catch Accuracy: 76.14678899082568 %
# 'Try me again B'

# %%
try_me_b(5, 30)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_48 (LSTM)              (None, 46, 128)           66560
#
#  lstm_49 (LSTM)              (None, 46, 64)            49408
#
#  dense_48 (Dense)            (None, 46, 64)            4160
#
#  dropout_32 (Dropout)        (None, 46, 64)            0
#
#  lstm_50 (LSTM)              (None, 32)                12416
#
#  dense_49 (Dense)            (None, 32)                1056
#
#  dropout_33 (Dropout)        (None, 32)                0
#
#  dense_50 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 5s 133ms/step - loss: 0.4072 - val_loss: 0.2932
# Epoch 2/100
# 10/10 [==============================] - 1s 122ms/step - loss: 0.2458 - val_loss: 0.3145
# Epoch 3/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.2232 - val_loss: 0.3937
# Epoch 4/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2130 - val_loss: 0.2468
# Epoch 5/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.2014 - val_loss: 0.2225
# Epoch 6/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1948 - val_loss: 0.2171
# Epoch 7/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1840 - val_loss: 0.2516
# Epoch 8/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.1797 - val_loss: 0.2272
# Epoch 9/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.1533 - val_loss: 0.1235
# Epoch 10/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.1036 - val_loss: 0.0784
# Epoch 11/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0971 - val_loss: 0.0876
# Epoch 12/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0856 - val_loss: 0.0787
# Epoch 13/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0943 - val_loss: 0.0326
# Epoch 14/100
# 10/10 [==============================] - 1s 93ms/step - loss: 0.0857 - val_loss: 0.1256
# Epoch 15/100
# 10/10 [==============================] - 1s 140ms/step - loss: 0.0846 - val_loss: 0.1096
# Epoch 16/100
# 10/10 [==============================] - 1s 117ms/step - loss: 0.0828 - val_loss: 0.1135
# Epoch 17/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0802 - val_loss: 0.0795
# Epoch 18/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0749 - val_loss: 0.0870
# Epoch 19/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0762 - val_loss: 0.0270
# Epoch 20/100
# 10/10 [==============================] - 1s 91ms/step - loss: 0.0788 - val_loss: 0.0263
# Epoch 21/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0784 - val_loss: 0.0270
# Epoch 22/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0740 - val_loss: 0.0434
# Epoch 23/100
# 10/10 [==============================] - 1s 89ms/step - loss: 0.0709 - val_loss: 0.0581
# Epoch 24/100
# 10/10 [==============================] - 1s 90ms/step - loss: 0.0719 - val_loss: 0.0358
# Epoch 25/100
# 10/10 [==============================] - 1s 94ms/step - loss: 0.0742 - val_loss: 0.0254
# Epoch 26/100
# 10/10 [==============================] - 1s 87ms/step - loss: 0.0682 - val_loss: 0.0305
# Epoch 27/100
# 10/10 [==============================] - 1s 103ms/step - loss: 0.0684 - val_loss: 0.0273
# Epoch 28/100
# 10/10 [==============================] - 1s 142ms/step - loss: 0.0722 - val_loss: 0.0336
# Epoch 29/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0726 - val_loss: 0.0247
# Epoch 30/100
# 10/10 [==============================] - 1s 92ms/step - loss: 0.0698 - val_loss: 0.0895
# Evaluate model on test data
# 4/4 [==============================] - 0s 19ms/step
# --------------------------------------------------------
# test MAPE: 9.616696079226235 %
# -------------------------------------------------------
# Trend Catch Accuracy: 78.89908256880734 %
# 'Try me again B'

# %%
try_me_b(5, 40)
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_54 (LSTM)              (None, 56, 128)           66560
#
#  lstm_55 (LSTM)              (None, 56, 64)            49408
#
#  dense_54 (Dense)            (None, 56, 64)            4160
#
#  dropout_36 (Dropout)        (None, 56, 64)            0
#
#  lstm_56 (LSTM)              (None, 32)                12416
#
#  dense_55 (Dense)            (None, 32)                1056
#
#  dropout_37 (Dropout)        (None, 32)                0
#
#  dense_56 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 133765 (522.52 KB)
# Trainable params: 133765 (522.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 6s 150ms/step - loss: 0.4824 - val_loss: 0.6231
# Epoch 2/100
# 10/10 [==============================] - 2s 205ms/step - loss: 0.3756 - val_loss: 0.5255
# Epoch 3/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.2967 - val_loss: 0.3353
# Epoch 4/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2325 - val_loss: 0.2272
# Epoch 5/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.2018 - val_loss: 0.2236
# Epoch 6/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.1999 - val_loss: 0.2227
# Epoch 7/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1946 - val_loss: 0.2304
# Epoch 8/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1861 - val_loss: 0.2173
# Epoch 9/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.1897 - val_loss: 0.2913
# Epoch 10/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.1912 - val_loss: 0.2367
# Epoch 11/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1762 - val_loss: 0.2085
# Epoch 12/100
# 10/10 [==============================] - 2s 161ms/step - loss: 0.1844 - val_loss: 0.2100
# Epoch 13/100
# 10/10 [==============================] - 1s 127ms/step - loss: 0.1803 - val_loss: 0.2744
# Epoch 14/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.1878 - val_loss: 0.2212
# Epoch 15/100
# 10/10 [==============================] - 1s 112ms/step - loss: 0.1550 - val_loss: 0.2169
# Epoch 16/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0984 - val_loss: 0.1568
# Epoch 17/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0936 - val_loss: 0.0697
# Epoch 18/100
# 10/10 [==============================] - 1s 108ms/step - loss: 0.0919 - val_loss: 0.0423
# Epoch 19/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0888 - val_loss: 0.0359
# Epoch 20/100
# 10/10 [==============================] - 1s 118ms/step - loss: 0.0833 - val_loss: 0.0665
# Epoch 21/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0847 - val_loss: 0.0916
# Epoch 22/100
# 10/10 [==============================] - 1s 128ms/step - loss: 0.0765 - val_loss: 0.0958
# Epoch 23/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.0783 - val_loss: 0.0370
# Epoch 24/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0805 - val_loss: 0.1135
# Epoch 25/100
# 10/10 [==============================] - 1s 113ms/step - loss: 0.0765 - val_loss: 0.0738
# Epoch 26/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0784 - val_loss: 0.0418
# Epoch 27/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0734 - val_loss: 0.0372
# Epoch 28/100
# 10/10 [==============================] - 2s 180ms/step - loss: 0.0770 - val_loss: 0.0620
# Epoch 29/100
# 10/10 [==============================] - 2s 185ms/step - loss: 0.0701 - val_loss: 0.0813
# Epoch 30/100
# 10/10 [==============================] - 1s 125ms/step - loss: 0.0667 - val_loss: 0.0394
# Epoch 31/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0655 - val_loss: 0.0630
# Epoch 32/100
# 10/10 [==============================] - 1s 145ms/step - loss: 0.0673 - val_loss: 0.0388
# Epoch 33/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0609 - val_loss: 0.0453
# Epoch 34/100
# 10/10 [==============================] - 1s 107ms/step - loss: 0.0663 - val_loss: 0.0366
# Epoch 35/100
# 10/10 [==============================] - 1s 109ms/step - loss: 0.0670 - val_loss: 0.0541
# Epoch 36/100
# 10/10 [==============================] - 1s 110ms/step - loss: 0.0676 - val_loss: 0.0574
# Epoch 37/100
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0665 - val_loss: 0.0605
# Evaluate model on test data
# 4/4 [==============================] - 0s 23ms/step
# --------------------------------------------------------
# test MAPE: 4.3859529299633095 %
# -------------------------------------------------------
# Trend Catch Accuracy: 77.98165137614679 %
# 'Try me again B'

# %%
try_me_b(10, 40)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_78 (LSTM)              (None, 51, 128)           66560
#
#  lstm_79 (LSTM)              (None, 51, 64)            49408
#
#  dense_78 (Dense)            (None, 51, 64)            4160
#
#  dropout_52 (Dropout)        (None, 51, 64)            0
#
#  lstm_80 (LSTM)              (None, 32)                12416
#
#  dense_79 (Dense)            (None, 32)                1056
#
#  dropout_53 (Dropout)        (None, 32)                0
#
#  dense_80 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 133930 (523.16 KB)
# Trainable params: 133930 (523.16 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 5s 137ms/step - loss: 0.4653 - val_loss: 0.5557
# Epoch 2/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.2870 - val_loss: 0.2628
# Epoch 3/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.2114 - val_loss: 0.2337
# Epoch 4/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.1902 - val_loss: 0.2039
# Epoch 5/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.1708 - val_loss: 0.1495
# Epoch 6/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.1590 - val_loss: 0.1338
# Epoch 7/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.1617 - val_loss: 0.1508
# Epoch 8/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1517 - val_loss: 0.1517
# Epoch 9/100
# 10/10 [==============================] - 1s 134ms/step - loss: 0.1412 - val_loss: 0.1772
# Epoch 10/100
# 10/10 [==============================] - 1s 143ms/step - loss: 0.1530 - val_loss: 0.1438
# Epoch 11/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1410 - val_loss: 0.1639
# Epoch 12/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1437 - val_loss: 0.1403
# Epoch 13/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.1394 - val_loss: 0.1575
# Epoch 14/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.1419 - val_loss: 0.1459
# Epoch 15/100
# 10/10 [==============================] - 1s 97ms/step - loss: 0.1360 - val_loss: 0.1427
# Epoch 16/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1325 - val_loss: 0.1256
# Epoch 17/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1340 - val_loss: 0.1784
# Epoch 18/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.1273 - val_loss: 0.1285
# Epoch 19/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.1313 - val_loss: 0.1349
# Epoch 20/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.1255 - val_loss: 0.1230
# Epoch 21/100
# 10/10 [==============================] - 2s 158ms/step - loss: 0.1124 - val_loss: 0.0895
# Epoch 22/100
# 10/10 [==============================] - 1s 123ms/step - loss: 0.0930 - val_loss: 0.1603
# Epoch 23/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0868 - val_loss: 0.0415
# Epoch 24/100
# 10/10 [==============================] - 1s 99ms/step - loss: 0.0825 - val_loss: 0.0441
# Epoch 25/100
# 10/10 [==============================] - 1s 100ms/step - loss: 0.0813 - val_loss: 0.0850
# Epoch 26/100
# 10/10 [==============================] - 1s 96ms/step - loss: 0.0795 - val_loss: 0.1281
# Epoch 27/100
# 10/10 [==============================] - 1s 98ms/step - loss: 0.0732 - val_loss: 0.0590
# Epoch 28/100
# 10/10 [==============================] - 1s 111ms/step - loss: 0.0696 - val_loss: 0.0631
# Epoch 29/100
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0740 - val_loss: 0.0403
# Epoch 30/100
# 10/10 [==============================] - 1s 102ms/step - loss: 0.0727 - val_loss: 0.0393
# Epoch 31/100
# 10/10 [==============================] - 1s 101ms/step - loss: 0.0698 - val_loss: 0.0578
# Epoch 32/100
# 10/10 [==============================] - 1s 141ms/step - loss: 0.0719 - val_loss: 0.1039
# Evaluate model on test data
# 4/4 [==============================] - 0s 26ms/step
# --------------------------------------------------------
# test MAPE: 10.326777039253386 %
# -------------------------------------------------------
# Trend Catch Accuracy: 78.89908256880734 %
# 'Try me again B'

# %%
try_me_b(30, 90)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_81 (LSTM)              (None, 81, 128)           66560
#
#  lstm_82 (LSTM)              (None, 81, 64)            49408
#
#  dense_81 (Dense)            (None, 81, 64)            4160
#
#  dropout_54 (Dropout)        (None, 81, 64)            0
#
#  lstm_83 (LSTM)              (None, 32)                12416
#
#  dense_82 (Dense)            (None, 32)                1056
#
#  dropout_55 (Dropout)        (None, 32)                0
#
#  dense_83 (Dense)            (None, 30)                990
#
# =================================================================
# Total params: 134590 (525.74 KB)
# Trainable params: 134590 (525.74 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/100
# 10/10 [==============================] - 65s 194ms/step - loss: 0.5029 - val_loss: 0.6198
# Epoch 2/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.3849 - val_loss: 0.6598
# Epoch 3/100
# 10/10 [==============================] - 1s 148ms/step - loss: 0.3523 - val_loss: 0.4940
# Epoch 4/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.2765 - val_loss: 0.3289
# Epoch 5/100
# 10/10 [==============================] - 2s 174ms/step - loss: 0.2251 - val_loss: 0.3161
# Epoch 6/100
# 10/10 [==============================] - 2s 212ms/step - loss: 0.1763 - val_loss: 0.1919
# Epoch 7/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.1444 - val_loss: 0.1233
# Epoch 8/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.1303 - val_loss: 0.1552
# Epoch 9/100
# 10/10 [==============================] - 2s 193ms/step - loss: 0.1200 - val_loss: 0.0846
# Epoch 10/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.1168 - val_loss: 0.0963
# Epoch 11/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1099 - val_loss: 0.0822
# Epoch 12/100
# 10/10 [==============================] - 2s 162ms/step - loss: 0.1009 - val_loss: 0.0992
# Epoch 13/100
# 10/10 [==============================] - 2s 223ms/step - loss: 0.1057 - val_loss: 0.0950
# Epoch 14/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.1008 - val_loss: 0.1086
# Epoch 15/100
# 10/10 [==============================] - 1s 154ms/step - loss: 0.0938 - val_loss: 0.0632
# Epoch 16/100
# 10/10 [==============================] - 2s 157ms/step - loss: 0.0913 - val_loss: 0.1097
# Epoch 17/100
# 10/10 [==============================] - 1s 153ms/step - loss: 0.0895 - val_loss: 0.0812
# Epoch 18/100
# 10/10 [==============================] - 1s 151ms/step - loss: 0.0938 - val_loss: 0.0826
# Epoch 19/100
# 10/10 [==============================] - 2s 160ms/step - loss: 0.0839 - val_loss: 0.0471
# Epoch 20/100
# 10/10 [==============================] - 2s 212ms/step - loss: 0.0815 - val_loss: 0.0825
# Epoch 21/100
# 10/10 [==============================] - 2s 167ms/step - loss: 0.0843 - val_loss: 0.0775
# Epoch 22/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0850 - val_loss: 0.0795
# Epoch 23/100
# 10/10 [==============================] - 1s 154ms/step - loss: 0.0802 - val_loss: 0.0514
# Epoch 24/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0790 - val_loss: 0.0417
# Epoch 25/100
# 10/10 [==============================] - 1s 152ms/step - loss: 0.0746 - val_loss: 0.0351
# Epoch 26/100
# 10/10 [==============================] - 2s 194ms/step - loss: 0.0756 - val_loss: 0.0376
# Epoch 27/100
# 10/10 [==============================] - 2s 205ms/step - loss: 0.0766 - val_loss: 0.0392
# Epoch 28/100
# 10/10 [==============================] - 2s 183ms/step - loss: 0.0714 - val_loss: 0.0450
# Epoch 29/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0718 - val_loss: 0.0371
# Epoch 30/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0724 - val_loss: 0.0441
# Epoch 31/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0745 - val_loss: 0.0357
# Epoch 32/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0682 - val_loss: 0.0343
# Epoch 33/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0728 - val_loss: 0.0348
# Epoch 34/100
# 10/10 [==============================] - 2s 169ms/step - loss: 0.0679 - val_loss: 0.0340
# Epoch 35/100
# 10/10 [==============================] - 2s 218ms/step - loss: 0.0686 - val_loss: 0.0442
# Epoch 36/100
# 10/10 [==============================] - 2s 159ms/step - loss: 0.0669 - val_loss: 0.0483
# Epoch 37/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0668 - val_loss: 0.0803
# Epoch 38/100
# 10/10 [==============================] - 2s 156ms/step - loss: 0.0635 - val_loss: 0.0394
# Epoch 39/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0646 - val_loss: 0.0352
# Epoch 40/100
# 10/10 [==============================] - 2s 154ms/step - loss: 0.0636 - val_loss: 0.0327
# Epoch 41/100
# 10/10 [==============================] - 2s 155ms/step - loss: 0.0655 - val_loss: 0.0443
# Epoch 42/100
# 10/10 [==============================] - 2s 225ms/step - loss: 0.0638 - val_loss: 0.0578
# Evaluate model on test data
# 4/4 [==============================] - 0s 30ms/step
# --------------------------------------------------------
# test MAPE: 4.2603236732349945 %
# -------------------------------------------------------
# Trend Catch Accuracy: 88.07339449541286 %
# 'Try me again B'
